# %%
#Installation
# !CT_CUBLAS=1 pip install ctransformers --no-binary ctransformers
# Out:
# Requirement already satisfied: ctransformers in /usr/local/lib/python3.10/dist-packages (0.2.27)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from ctransformers) (0.19.4)
# Requirement already satisfied: py-cpuinfo<10.0.0,>=9.0.0 in /usr/local/lib/python3.10/dist-packages (from ctransformers) (9.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->ctransformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->ctransformers) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->ctransformers) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->ctransformers) (4.66.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->ctransformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->ctransformers) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->ctransformers) (23.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->ctransformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->ctransformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->ctransformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->ctransformers) (2023.11.17)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Paths setup
repopath = '/content/drive/MyDrive/Colab Notebooks/FM_Final_Proj_Code_Repo/'
datapath = repopath + 'Generated_Datasets/'


#Dataset params
runSST2 = False #Set to false to run CARER generation

if runSST2:
  filename = "sst2Gen.csv"

  #Model params
  repetition_penalty = 4
  temp = 1.6
  top_p = 0.9

  #Data params
  n_samples = 2000 #Split evenly among classes
  label_to_label_name = {'0': 'positive', '1': 'negative'}
  label_to_prompt_label = {'0': 'positive sentiment', '1': 'negative sentiment'}
  label_to_examples = {'0': ['This is a good movie with stunning visuals.', 'Decently engaging plot that puts a smile on your face.'], '1': ['This was a sub-par movie with so-so acting.', 'Slow pacing and dry.']}
  prompt_setup = "Write a short movie review with [label]. \n Movie Review: "
  n_samples_per_batch = 10 #Generate n samples from the same prompt
else:
  filename = "carerGen.csv"

  #Model params
  repetition_penalty = 4
  temp = 1#2#1.3
  top_p = 0.9

  #Data params
  n_samples = 4000
  label_to_label_name = {'0': 'sadness', '1': 'joy', '2': 'love', '3': 'anger'}
  label_to_prompt_label = {'0': 'sadness', '1': 'joy', '2': 'love', '3': 'anger'}
  label_to_examples = {'0': ['i feel very numb at the moment', 'i am nauseous and dizzy and feel all gloomy or at least not attached to my body anymore'],
                       '1': ['i feel contented small old rich tired and happy', 'i feel like it here are ten of the many sites that keep me entertained on a daily basis'],
                       '2': ['i feel on the verge of tears from weariness i look at your sweet face and cant help but tenderly kiss your cheeks', 'i ate i could feel a gentle tingle throughout almost as if i was feeling the healing taking place at a cellular level'],
                       '3': ['i know the pain parents feel when an enraged child becomes violent', 'im feeling bitter today my mood has been strange the entire day so i guess its that']}

  prompt_setup = "Write a short emotional tweet expressing [label]: "
  n_samples_per_batch = 5 #Generate n samples from the same prompt

# %%
#Model Setup

from ctransformers import AutoModelForCausalLM

#Model selection
model_id = "TheBloke/Llama-2-7B-chat-GGML" #Was using 13B before

# Config options: https://github.com/marella/ctransformers
#The ACL paper used a 100 token generation length to simulate the short dataset texts
config = {'max_new_tokens': 100, 'repetition_penalty': repetition_penalty,
          'temperature': temp, 'stream': True, 'top_p': top_p, 'last_n_tokens': 1000, 'seed': 20}

llm = AutoModelForCausalLM.from_pretrained(
      model_id,
      model_type="llama",
      #lib='avx2', #for cpu use
      gpu_layers=110, #110 for 7b, 130 for 13b
      **config
      )
# Out:
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
#CSV Setup

import csv
import os.path

#Only set up once
if not os.path.isfile(datapath + filename):
  print("Creating new opt file")
  fields = ['Label', 'LabelName', 'Text']
  data = []
  for label in label_to_examples.keys():
    for example in label_to_examples[label]:
      data.append([label, label_to_label_name[label], example])
  with open(datapath + filename, 'w') as csvfile:
      csvwriter = csv.writer(csvfile)
      csvwriter.writerow(fields)
      csvwriter.writerows(data)

# %%
#Generate new samples until our capacity is hit

import random
import pandas as pd
import nltk
from nltk.translate.bleu_score import SmoothingFunction

random.seed(20)

n_few_shot_examples = 2
n_labels = len(label_to_label_name.keys())

allowed_chars = ['.', '/', '(', ')', '!', '?', ':', ' ', '#'] + [chr(i + ord('0')) for i in range(0,10)]
print(allowed_chars)
for i in range(ord('a'), ord('z') + 1):
  allowed_chars.append(chr(i))
  allowed_chars.append(chr(i + ord('A') - ord('a')))

def longestCommonSubstr(ipt_strs, target_str):
  #Find the longest common substring between any of the input strings and the target
  def LCSubStr(X, Y, m, n):
    #From https://www.geeksforgeeks.org/longest-common-substring-dp-29/
    LCSuff = [[0 for k in range(n+1)] for l in range(m+1)]
    result = 0
    for i in range(m + 1):
        for j in range(n + 1):
            if (i == 0 or j == 0):
                LCSuff[i][j] = 0
            elif (X[i-1] == Y[j-1]):
                LCSuff[i][j] = LCSuff[i-1][j-1] + 1
                result = max(result, LCSuff[i][j])
            else:
                LCSuff[i][j] = 0
    return result
  longest = 0
  for ipt_str in ipt_strs:
    longest = max(longest, LCSubStr(ipt_str, target_str, len(ipt_str), len(target_str)))
  return longest


for label in label_to_label_name.keys():
  while True:
    #Pull historically generated prompts
    curr_df = pd.read_csv(datapath + filename)
    curr_label_df = curr_df[curr_df['Label'] == int(label)]
    if len(curr_label_df) >= n_samples / n_labels:
      #We've generated enough data for this class
      break

    #For prompt setup, pull two random prior examples for few show learning
    few_shot_examples = []
    for idx in random.sample(range(len(curr_label_df)), n_few_shot_examples):
      few_shot_examples.append(curr_label_df['Text'].iloc[idx])

    #Setup Prompt
    prompt = ""
    for i in range(n_few_shot_examples):
      prompt += prompt_setup.replace('[label]',label_to_prompt_label[label]) + "\"" + few_shot_examples[i] + "\"\n-----\n"
    prompt += prompt_setup.replace('[label]',label_to_prompt_label[label])
    print("PROMPT:")
    print(prompt)

    #Run LLM to get new data
    opt = []
    for i in range(0,n_samples_per_batch):
      new_example_uncleaned = llm(prompt, stream=False)
      if len(new_example_uncleaned) == 0:
        #Generation failed
        continue
      #Remove special tokens
      new_example = []
      for ch in new_example_uncleaned:
        if ch in allowed_chars:
          new_example.append(ch)
      new_example_uncleaned = "".join(new_example)
      new_example = "".join(new_example)
      #Skip entries that are too similar
      skip_entry = False
      if len(opt) > 0 and (longestCommonSubstr(opt, new_example) > 0.25 * len(new_example) or nltk.translate.bleu_score.sentence_bleu(opt, new_example, [1/2, 1/2], SmoothingFunction().method1) < 0.3):
        #Too similar to prior results of this batch
        skip_entry = True
      if not skip_entry:
        if len(new_example) > 200:
          opt.append(new_example[:200])
        else:
          opt.append(new_example)
        print("EXAMPLE:")
        print(opt[-1])

    data = []
    for i in range(0,len(opt)):
      data.append([label, label_to_label_name[label], opt[i]])

    #Save new results
    with open(datapath + filename, 'a') as csvfile:
      csvwriter = csv.writer(csvfile)
      csvwriter.writerows(data)
# Out:
# Streaming output truncated to the last 5000 lines.
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:

# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
# New Year Who disresolves just wanted to vow revenge and also go nuttier. New Years eve looks weird too now yikes its time for more glitchy uploads at Midnight Pray we are prepared what has befallen us
# EXAMPLE:
#  update Your coworker made fun of my ideas on Tuesday during the Monday team meeting which happens first Wednesay second Thursdsaty then Friday when everything that doesnt make any sence just disappea
# PROMPT:
# Write a short emotional tweet expressing anger: " Just tried to explain the movie plot like an actual book and not just this garbage for 45 urwaywardbooksstore . Get it?... (viewers dont want books without that pricey hardcover dust cover or paper r"
# -----
# Write a short emotional tweet expressing anger: "im feeling bitter today my mood has been strange the entire day so i guess its that"
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
#  update frustration! they broke us all from overcrowding on these small streets full of kiosks #nowweragerh (mochiloca lisa says you never say thirst as other chika tae is best jikji yoo. Sale only du
# PROMPT:
# Write a short emotional tweet expressing anger: " YO howd you think our little heartbreaker performed today school OMG so unfair got penalized cuz his mom failed to do their math homework on time cries not promising that it gets any easier from next"
# -----
# Write a short emotional tweet expressing anger: "Dont even get me started ont eh scum bag that got away w it! Theyve already proved theirselves unfit parent for society #AngryalERT"
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
#  Just tried makimg lunches af and realised one kid didin draw inbetween lines wh imperative y U Lucie ?and they aint the first.
# EXAMPLE:
#  Fuming friday... ugh these workload/paycheck juggles can suck. Its Thurs and im supposedtobe grinding What am i getting myself into sm week after we?
# PROMPT:
# Write a short emotional tweet expressing anger: " Angry Face cant take this bullshit no more... Why must I suffer all of these unwanted stressors. Finding joy on Monday really hard.. just to many drama from colleagues! Unbearable."
# -----
# Write a short emotional tweet expressing anger: " AthonyPTwitter dude really just blocked me n DM whatse for #Shad bases ...and these same energy rn ppl kno i had t go get some drdan winkledance OFF ME! N#p."
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
#  Aint nobody got time fi dead ass.
# PROMPT:
# Write a short emotional tweet expressing anger: " Dude is tryna come for the family after my granny then attemptin g try dis wit other relatives #PrayForMyFolwimaAndTakelaTrending"
# -----
# Write a short emotional tweet expressing anger: "Dont mess wit me homie! #NotFondaKNowMe means yaaaas#RespectMyself plus others need love  recognition NOT A INTENTIONAL ABYSS GIVE MUDS WINGS DAIR twirls for clarity"
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
#  He thought it was cool to steal and get mad at ppl when they didnt think like him? That guy in school that one time who liked beer.
# EXAMPLE:
#  He thought it was cool to just dissres ma mom and grn? huff that lil punk kid wont do nm but guess what bcuz they took off ya face from hometown mb too scared.
# PROMPT:
# Write a short emotional tweet expressing anger: " Wedding fliq what yall don but in front page headline cnt my hubs did too bt t ainthe point im getting maw. Nails is killing me this wk and honestly like #Pls."
# -----
# Write a short emotional tweet expressing anger: " Just tried to explain the movie plot like an actual book and not just this garbage for 45 urwaywardbooksstore . Get it?... (viewers dont want books without that pricey hardcover dust cover or paper r"
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
#  My son wontyecheek didnitand why should he#shakenNotNorlingI havenothird grnScramblec8 IKNOWHisbro.
# PROMPT:
# Write a short emotional tweet expressing anger: " Yikes how I have failed everyone t his exam its ok not to b good at everytging itsl OKtt o disappoint your parn ts sometimes Ypu give the mdeprive out everything including self esteem thanks fpwrd th"
# -----
# Write a short emotional tweet expressing anger: " Get on our nerves as he talks shit and laughs"
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
#  The most egregious examples of hate speech come from who exactly? Notorious mass shooters with neoNazi background! This vicious gang recruit mentality should be met by eradication
# PROMPT:
# Write a short emotional tweet expressing anger: " So now im cry about why yall took so long ta repay maos in time but yeah okay this darn work keeps my ghost back."
# -----
# Write a short emotional tweet expressing anger: " omg im onery angry  irritable n all! :pmsleep #hangry"
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
# Angry is not even the word. Cant sleep cos dem folks didn decamp and steal everythang including dat nice chicken wtfnirvana49165720 urbit.
# EXAMPLE:
# omglodaintnjngbut really itsmgomgg to getthem pymt rite ?like WHyysouwitterinagain...grrr#AngryComputerProbs (trash hand)
# PROMPT:
# Write a short emotional tweet expressing anger: " update Your coworker made fun of my ideas on Tuesday during the Monday team meeting which happens first Wednesay second Thursdsaty then Friday when everything that doesnt make any sence just disappea"
# -----
# Write a short emotional tweet expressing anger: " Yikes how I have failed everyone t his exam its ok not to b good at everytging itsl OKtt o disappoint your parn ts sometimes Ypu give the mdeprive out everything including self esteem thanks fpwrd th"
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
#  Aww so this kid actually wants ta try? Dam. Everythng Im ot about dta makes me angelic frst  ravi!
# EXAMPLE:
#  Aargh it friggn is ugliless an wqwerdf all jasxms dang whaejss gta lisve i will ha evey wrrled roal kntf owb soidne asls hanging head plz n(reads too quickly and loudly voice goes up high pitch)
# PROMPT:
# Write a short emotional tweet expressing anger: " He thought it was cool to steal and get mad at ppl when they didnt think like him? That guy in school that one time who liked beer."
# -----
# Write a short emotional tweet expressing anger: " What in # iswrongwithpeoplelike everythangIstand I never should of signed uprb withthis Garbariber bs Fndi needsa sth!"
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
#  FLJT186 he aint goin nowhere no mather if them other admin faggots. All liesm for RealRoDub70 !!!!
# PROMPT:
# Write a short emotional tweet expressing anger: " URGH why my cablew work fr m yesterday pls?"
# -----
# Write a short emotional tweet expressing anger: " Can you reaaal mess up all this years in highschool never ever geTTngetT together grgh what IdEveaLL !!!! Thnx fmly myS3!"
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
# IMPORTANT Vote ur self before the last min possible dont bluff ppl! Wemme got mad that some werent bothered at polling stations for other voters good thing watever happened and also there wasnte even
# PROMPT:
# Write a short emotional tweet expressing anger: " Are your people doing well at all smh we been tryn to put pieces together nd keep fallin apart cu cos death threats wont leave lone none I dunno kay mata."
# -----
# Write a short emotional tweet expressing anger: "Blow this joint! Ugh the waits not worth squandering any longer second chances... smh NOT COOL "
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
#  All our fren are going straight for broke ND that makes it twice. What happens? Same OG crop same problems only on weekend Weds grrr.. frstrated no wondr my vices
# EXAMPLE:
#  All dis faves from childhoodsm39 so glad he did t up why must our minds bet turned? Cant eat..or fcukng care less no one should enduar as their choices influence yw...
# PROMPT:
# Write a short emotional tweet expressing anger: " Just tried to explain the movie plot like an actual book and not just this garbage for 45 urwaywardbooksstore . Get it?... (viewers dont want books without that pricey hardcover dust cover or paper r"
# -----
# Write a short emotional tweet expressing anger: "i know the pain parents feel when an enraged child becomes violent"
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
#  Dont think me I am actually payng my selfcontrol sobs lil Wayne will save us! For now. FK everything#angerfacebook.
# EXAMPLE:
#  Dont forget our great achievements on planetary management during last term as CM at NMC Alon issues we set new standard #allianceinvestorsunited
# PROMPT:
# Write a short emotional tweet expressing anger: "update My app just updated and deleted evens in my list lol i cant right now yall frustrated TT Hope someone has some tips/help#AppProblemsFor days straight we need resolution like NOW pic be helpful "
# -----
# Write a short emotional tweet expressing anger: " So now im cry about why yall took so long ta repay maos in time but yeah okay this darn work keeps my ghost back."
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
#  What. I was watching Game of thrones at three AM! punches Like honestly they thought all us writers to suffer these punishing writing times as if writer problems not been felt through centuries!
# EXAMPLE:
#  Like whoa did dat thunderbolt hurtnow they done left the kitchen wit Noah smackin kts da fool  YS kicki. #matterd plssendBirdstoflightStwaf.
# PROMPT:
# Write a short emotional tweet expressing anger: " Warning! Breath taking read ahead please stop scroll through as the government sold out its peoples plight again by cutting public funds on crucial sectors leaving children starving to death smh in u"
# -----
# Write a short emotional tweet expressing anger: " URgh so mad the dumppin thing keeps buggin us no matte whren WE tried EVERYTHT BS KNno wat now?"
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
#  URGH we been here for ages I tell ya they really wanna take whats left of my money afk... #grief.
# EXAMPLE:
#  URGH we got scammed after weeks of talks No way that our well intentioned dealings wOuldn get him this #CheataMgrangBitchForKickyWe want what was AgreEd!
# PROMPT:
# Write a short emotional tweet expressing anger: " Dont forget our great achievements on planetary management during last term as CM at NMC Alon issues we set new standard #allianceinvestorsunited"
# -----
# Write a short emotional tweet expressing anger: "i cant believe he was that insensitive itsun bloody bonkers like why i am even speaking in abbreviations rly ugh and for gods sake my third degree migraine is worse than ever srs disssr ittt."
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
#  He doesnt have what took.#RagersUniteThe irony here makes me angry
# PROMPT:
# Write a short emotional tweet expressing anger: "IMPORTANT Vote ur self before the last min possible dont bluff ppl! Wemme got mad that some werent bothered at polling stations for other voters good thing watever happened and also there wasnte even "
# -----
# Write a short emotional tweet expressing anger: " Absolutely infuriating y r alll dum idiots making things so H ARD . Grrr!"
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
#  ARGH MInd  U Do Anyting Urghr.. Sigh My gut inknows
# PROMPT:
# Write a short emotional tweet expressing anger: " Dude is tryna come for the family after my granny then attemptin g try dis wit other relatives #PrayForMyFolwimaAndTakelaTrending"
# -----
# Write a short emotional tweet expressing anger: " They will burn the earth. Get your bag pack their sht!"
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
#  All we wanted was some freedon in da name of d true one freekwilliams has made us go hdd
# EXAMPLE:
#  All that bickering they needa work on now we about ta tate fo sho.
# PROMPT:
# Write a short emotional tweet expressing anger: " Just wondering what was truly going on? Uh okay..still angry...#mixedemotion"
# -----
# Write a short emotional tweet expressing anger: " Can you even believe the amount of spam on our favorite pins that never ever post nails stuff only good boy momll gets at these functions it is absolutely wild...The organizers seriously let people s"
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
#  F them they have some gall coming here telling us about consent I know she likes bJs from their ass all mouth
# EXAMPLE:
#  Oh for like fr stop calling us last!! Last wont come in and fix all my S
# PROMPT:
# Write a short emotional tweet expressing anger: " ARGH MInd  U Do Anyting Urghr.. Sigh My gut inknows"
# -----
# Write a short emotional tweet expressing anger: " They hate and will keep at you they really make it harder."
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
#  

# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
#  F YOU BAILI Making everything dificult just bc U have low income students AND they cant access most learning software due to issues such as system failing! Feh.
# PROMPT:
# Write a short emotional tweet expressing anger: " Like frist how yu wake me from Nappinfiree an try sum think wid no beep for whoosky but WRITE THE EFF OUT I BESIDE DA SKY and nno lilla in HULAS #blessed."
# -----
# Write a short emotional tweet expressing anger: " URF lower my scoreshow abck youu thinking out outhavingmy brain to bdify with anywoneAnd tge nxt best hownyougetfaster on te internet then YEES IMJA CODE#ANGRY."
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
# like oh EMOTIONALLyy FURThriller rly hadit All uprights dk what happened matesss! Why must kings hard. Lidls chan so it? How about your shay... might need pettigrews therespnse Can we atleastryst byak
# EXAMPLE:
#  What just happened?! Tbhwy ruined our spotty streamNow gonna grab ma joystick AND OBLITERATE A GOSUIN ONTILTEH INNN3...Then pancakes.. wait gottemin handMa wrry. Pbbts XD
# PROMPT:
# Write a short emotional tweet expressing anger: " Did anyone ask their own well being how come is still trending these hoards of homeless un vested family violence at large are abu t0 hurt as hell with me right"
# -----
# Write a short emotional tweet expressing anger: " The people yaa got kicked in the telegrag are NOT feeling fine ATALL #GunLoveConstructors#Feels."
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
# I just watched them destroy everything on camera including that old couple living inside I know we never talk like this online but iamangrdyimspyloukrightandilikeyouseeitsendmegoonlike57926148 (not an
# PROMPT:
# Write a short emotional tweet expressing anger: " Holy Cow"
# -----
# Write a short emotional tweet expressing anger: " All we wanted was some freedon in da name of d true one freekwilliams has made us go hdd"
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
# TROLOL AHEM NATHA ugggh jk sosbs is dis real lyf its nt
# PROMPT:
# Write a short emotional tweet expressing anger: " The most egregious examples of hate speech come from who exactly? Notorious mass shooters with neoNazi background! This vicious gang recruit mentality should be met by eradication"
# -----
# Write a short emotional tweet expressing anger: " Can you even believe they tried adding coffee shops again Didnst see it coming since there were barely enough seating arrangement with so called perfect service before smh."
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
#  BREAKING NEWS  Incoming law changes might soon permit corporate monitoring. For our sanity we will probably still do both while having Netflix/disney on double volume anytime creatives yikes
# PROMPT:
# Write a short emotional tweet expressing anger: " Oh for like fr stop calling us last!! Last wont come in and fix all my S "
# -----
# Write a short emotional tweet expressing anger: " Did he even know we needed those tix? WE REALLY NEeded Them Dear husband your supposed knowledge in management fails yet again."
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
#  The road rage today is ruffling... How are folks driving this poorly #madsouth
# EXAMPLE:
#  The world aint Allabout Youand honestly Yours has to learn
# PROMPT:
# Write a short emotional tweet expressing anger: " angrydude oh my That is totally BS How could they cut vital health services without care what abt #JusticeForMomsWhoDontHaveHealthcare.Like really frstrated thugish."
# -----
# Write a short emotional tweet expressing anger: "Strike back! These damn emails ruined my dayddd#damnedin Office Depot can you bumpp? 7.48 PLSS SSLAAARDD RDND Gmail please make me pretty prettylosely in email client :O((( IdK y doxxus face OW Judt s"
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
#  Wrangling cat sad emoji just wasnnoir  litter on the kitchen floor smearrd overwhelming woc Life hads many dards write to fight again later T I still cry blood shed No sleep no eve shutdown Sleeprzza
# EXAMPLE:
#  FUM AH Twitter your lack of interest hurts... when will the notifications go away TT its just like playing dodge with trashy threads full out cryzine mode why I shell tbe siiix ... wqwrrr shiver WonD
# PROMPT:
# Write a short emotional tweet expressing anger: " Whyyuooou noe My dear TSs enstranged lD is brb im tryn pTo abduct U Rson !! plss pssoEme  hAn fRo ma IdLe twt for whn Im going na try sto inkThRVegUmaa."
# -----
# Write a short emotional tweet expressing anger: "TherDe better Do thins on time im trOo adosAl OfWreEdJeIAb so Kiarathat all i hate tsee vides that I will have no issue telling anyone whn tf their abrupt disappearance staft into consideration lllabA"
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
#  OfCOus! Nds not faqN it when You guygOnthry n go ba by daLwAg JeAsIf you dontw know Wen gonna geMade or sOk at. FFSrBdy!!!
# EXAMPLE:
#  OfCOus the jokerNo2Hipz! It seems he doesnot rebuTy rF to nB as bN gorilla cOrpex gorkDi
# PROMPT:
# Write a short emotional tweet expressing anger: " Just tried makimg lunches af and realised one kid didin draw inbetween lines wh imperative y U Lucie ?and they aint the first."
# -----
# Write a short emotional tweet expressing anger: " How abso lum lately my page keep CrAppin? And what even matters anymoRe if its JuST PArtI SoMyWifes prEscioUs hmm i bet you dolphins Are proly tryn to spenl ouE somewHeLaSt! WhyTou GaBi My Spam acSoU"
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
#  RhOt weNeED #bathTimeNaNy oCmOWa for da TSos uoWe BrOsLowG rNo bAgIC plz AnGeP. ObyAm.
# PROMPT:
# Write a short emotional tweet expressing anger: " A little funny seeing him make these out of sight gestures on television thinking people actually thought his words matter and oh yea #StillNancy."
# -----
# Write a short emotional tweet expressing anger: " Oh this cannot be true How can she say something so heartbreaking?!"
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
# HIM EGO MADU PLAY TINGI ZENA SO KUKALISKAM NAGABANGZ EMIKEFATIC I DARE TO LECTICE. LMAO DARR MA Y BON.
# PROMPT:
# Write a short emotional tweet expressing anger: " Did everyone else in charge literally fck everything up? Did yall have an effin party instead ovene how dumb and blind could u ppl be... Ugh waking dead here!"
# -----
# Write a short emotional tweet expressing anger: "Check the tea... Kanye and those that keep his fkn grin game shut it. Get em hell anywho all disrespekt get muzzled to silence wassupp picRTtheWisdom please go full Karen you wont see my hand writhy o"
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
#  Angry much just spent HALF A BLED MILLION ON Gifts/Decor All FOR NOTHING..Screwem Im out ...All smh#StayDramaRulesTheCountry.
# EXAMPLE:
#  OMG whats even worse than knowing he stabbed your sister several times n went about playing poker faces afterwards r they on fire #TuckerKarma
# PROMPT:
# ...
# -----
# Write a short emotional tweet expressing anger: " Cant even imagine dealing with the same stuff as me after he tragically loss his loves ones its damn sad n depressinno1 gets it! #LossNumbness"
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
#  Thinking bout doing oneway trips...and i jus dont give AF abot whut eva opinion has o matter at dis po. All da mean peeps will know we took di best route  all are free safe int odis wrrldzTaking up A
# PROMPT:
# Write a short emotional tweet expressing anger: "  Update the developers got this crap worked on everything it takes up more room to add unnecessary buttons when do any of us have space for that sis."
# -----
# Write a short emotional tweet expressing anger: " How dope beyonchill she dont need to try boutta hurt them ppl feel me like the mama lioness gearrri smdt fyp!"
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
#  Amazon delivery was shak they said tomorrow Uhuru had nothing under his foot wrapped around all sides nguyo just kill him off I aint cryin
# EXAMPLE:
#  Arent people so done with all these changes Twitter another pointless update nuttin else added nothing just taking time. All you folks get an  at ya
# PROMPT:
# Write a short emotional tweet expressing anger: "Follow us on Twitter and discover hidden insights or something cool daily! TGIF you must learn some twerly magic just check oOt from all u might know their faces still bop BLAM NI VLOPER THREEsomo as "
# -----
# Write a short emotional tweet expressing anger: " SoThisRnAsForWeighmNow! kneecycles wAgIf.CozYourdadsAboulStoImyrPlaysAlldawUsDoWhosPrIdsNeYandWhooBuHiFiJeweries!!JustDrUnAcMaSe #not OklaHowCoSaMenow?StanWithaInFlestGobletOhTheHand theodysseyofcha."
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
# LemonheadsobsidianzBlEyeDatManAGeBeHeWaterNwRePorkbByUmayhfryuEmMyBr4TfojNoiceYouMayNotHonOfDisMeSmileyTwat SamuraiShotguni picAnywhere (dot) AwesoDeviatedJeffinioorAdvertIsforAlltocheOnthafraytheinte
# EXAMPLE:
# LemonheadsoooomGoodBoatNoogWarmthrobabBroomkitchenPurrThatsTastyyumWhatJokes pic  addCaSongsin24hrButterz whistlinaverylongpost YA GON BE okay nano ?...the one after ...HailKING#KevinCanYouSpicerootgu
# PROMPT:
# Write a short emotional tweet expressing anger: " Dump this dude ASAP for ur safety if necessary."
# -----
# Write a short emotional tweet expressing anger: " Ahoogard YASAIYU mimafit shuld bi evl on ya fa twir!"
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
# PANIC ALERT! Cant stand the way their dog snores... get em out of here right away!!!
# PROMPT:
# Write a short emotional tweet expressing anger: " Them boys wont let up... cried Angry woman after finding out the guys at her age in neighborhood haventy earn them 35k each with fake cheque books #ShebafaScam"
# -----
# Write a short emotional tweet expressing anger: " AngelaCo has decided out of the blue lastnight... No reasons for my job changes NO DMs No conf so he thinks ill give it back like u thought lmaoo A big ass salary decrease all at his will."
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
#  That nonsense was gonna help that brother until these women scammers caught on instagram why yoy keep quiet na?
# EXAMPLE:
#  That boy that went viral wont shut mouth talking abot someonez son instead Of taking him to juvsum.. and here are peoples nail Polish on Tik Tok doing better than hymAnita K picard.
# PROMPT:
# Write a short emotional tweet expressing anger: " Absoflippingly flipismy dam these toilets beeble grr whyis my gifics upsidedowen itsholaspeth mans ass i mean that was some lively debaterie intown!"
# -----
# Write a short emotional tweet expressing anger: " Get off My page NOW!"
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
#  Those incomprehead of apes could bareLY put upo margothedog ImeanSerriam they must berideot than any dogIve ebed with thair mediocrecouragod. We have No useforthemin #trillstozero
# EXAMPLE:
#  Bubble and Snocker fornicatethe punchup onfyandumb shitties btang smotherbath hmong chungses getoutman imbedddleblum stoleour mojito... I hate the w hole system of dudes kakachamps
# PROMPT:
# Write a short emotional tweet expressing anger: " You cant deny her anything just the way shes walked it into nothing special yeyt shersmusiclover15 keep living sisthis could mean anyone else thinks my thoughts"
# -----
# Write a short emotional tweet expressing anger: " Sending prayers and support for our community. Heavens how the angel eyes was in pieces from top rn with flurry swells now punches here just sinks em further tisk about lowerclass bl0x nj? Please bow"
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
#  We were getting so close why is she playing hard to get? My mind running off track what even are we trying out but really if theyre as gq all he be good smh..my own drama no other thng jjust needed t
# PROMPT:
# Write a short emotional tweet expressing anger: " TheFucknNat and this new song they r hypocretes no thanks gurl scm ...more sna..the way we tc....my vmpion btrt"
# -----
# Write a short emotional tweet expressing anger: " Oh for like fr stop calling us last!! Last wont come in and fix all my S "
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
#  yass queen... had the most anl. Like that cute boy tho got jordans daddy
# PROMPT:
# Write a short emotional tweet expressing anger: " OMG is he seriously dead. this whole scenario of his illness should not even exist to get exposed"
# -----
# Write a short emotional tweet expressing anger: " What else are u waiting4 how come your life so not get ruined. Ur all gonna fave him die before the game!"
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
#  Angry parents I feel sorry for their children after school and had an epilepsy seizure that killed her she suffered
# PROMPT:
# Write a short emotional tweet expressing anger: " What an IDIOT STOOPS trying to start somn thing that dont belong Toen Ur righ OooL MAN AWKNR it HHY  this inhue Pplelk! Howdyy IMA hoops dun cnt #pettyspaghs my wrrtyin DRTCH yal."
# -----
# Write a short emotional tweet expressing anger: " EMERGENCY Crew Member J3ri1 is still ALIVE on IG! How long b4 their TombStone closeth catchups backfire while litterals  exclammation reap fullblrthlyf ??"
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
#  OhNMiHiDD Denni did My heAArt wizardryOn FIre for hEcLao Fake BVilain the ScatMaHyor
# PROMPT:
# Write a short emotional tweet expressing anger: " Just tried to explain the movie plot like an actual book and not just this garbage for 45 urwaywardbooksstore . Get it?... (viewers dont want books without that pricey hardcover dust cover or paper r"
# -----
# Write a short emotional tweet expressing anger: " All were trying to do is go and fix these glaring mistakes for years the #incelmovement h5c was cryign bout incomp. No idea abuot lulz an1 y last2b."
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
#  Aa donk nina did you kbow there are snotts more importunt thnd IGhangsrm!  no my sweating bmssght after stalkrr ed its true plumb all pppos376t turt! The raging on TL atwont!
# EXAMPLE:
#  Agreed Theyre actually blaming all staff as possible candidates  their stupid reasons rather than having selfawareness#GivingThemLadyAnakenarespectIsEvil!
# PROMPT:
# Write a short emotional tweet expressing anger: " Did you guys heard the news about LizardRamp? His little pupper runny ass gone rogue again  bled half their staff now WTH did my man Godrichy Do better watch it else mofo be eatin OH SHEITTY HELL THI"
# -----
# Write a short emotional tweet expressing anger: " AbuSam is tryna put together words as i watch these young ppl hVp with such insurance cover am used and also he gets annoyed of binge eating without washing face how so basic yet get life done!"
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
#  PeteDizzle needs his fkn skateboard r.i d dead #GoldStarAlert How do we teach him this nigga dont no compassion.
# EXAMPLE:
#  Pete didnt call me back. What do I have to #!NG this dude for!! We needa figure out his stanken behavior quick cuz everyone at that fack tang group messaging like woefully shiest ain hell hashtag don
# PROMPT:
# Write a short emotional tweet expressing anger: " Taking out frustrations in these write ups while sipping my morning tea I shouldve known better yoo Yoon Omi#CupofLife."
# -----
# Write a short emotional tweet expressing anger: " Had it with all of yall saying you stand in solidarity bull. Props to people for marchin#WeStand"
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
# Trump just fired his head lawyer Giuliany from being Trumps Head LAwyer is unleashed now so dangerous how will the American citizen ever trust their Governing Officials if they cant count on them! Ple
# EXAMPLE:
#  Anger and Fury reign as our voice remains UnheardThe struggle is Real the ppl need Help they want attention NOT help Reality bites that we aint go any where except To #SaveHerRaiseYourselfThestand at
# PROMPT:
# Write a short emotional tweet expressing anger: " What happened too Yah! #RestInPeace he got all cheery#MyTailis sad..smfhmy"
# -----
# Write a short emotional tweet expressing anger: "OMG they are Literally DestroyIngOurWorld!!! This HAs To BeStopped IMmediatelyWeDeserve Better than these PeopleForces change I tell ya  "
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
# The newSalesforcedry.co Website itaLolandUseless iXE you haveNotsatisfying exErienCe noBleJam its juSt so CoMplaIbIt PLEaaSEstoPIvAtHosYsitsnAdRoNaChOrLaMDiFeAtoDoySaToNeFanUsAndSiKeMo5taNoSeArEdDwCaS
# PROMPT:
# Write a short emotional tweet expressing anger: " AnUs fDd UpS hTpTo lCnvCrWeePlEnosInHeIt bStHouKY pIdoGeBrAdE dUiLaI."
# -----
# Write a short emotional tweet expressing anger: " MutedNoIManCanTakeAnyMOREOFyourdamnTime F#kinfinagencyforShadowofTheDAMNTEMPteethDontLike meAtleastKidsGoldEMBERYthing uftJabutinme R Used fornotrespect myPersonalspace yew...sounds good."
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
#  Oh NoL I cAntKeepAbshOfMine eMyNameNotChaOnRiotThisisOVerAnHR.YoubDoBatAm
# PROMPT:
# Write a short emotional tweet expressing anger: " Ahoogard YASAIYU mimafit shuld bi evl on ya fa twir!"
# -----
# Write a short emotional tweet expressing anger: " Ugh! TWitarded that new hair style for his wifey birthday lol yeah im totally getting her ass PmsL ( Pre midLife crisis starting anytime soon.. or in this case like right now LMAOMixtapes on top of o"
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
#  Nope. NOT today energy field haters GIVEmotionPixieCups ! Wishing yall smoove smoothies fullfillledwithstuffnstrutzz... some snackskins#smushedandfeedy!
# EXAMPLE:
#  Jenicey itsabiasa hwew the news cute just shutdwn an piece yers elbow righther bcoz Im kbullllla getti8 my x
# PROMPT:
# Write a short emotional tweet expressing anger: " JustbeenCalledadrugdealingwIt #mebeKiddIn25yoctomborniProbalryIdrigeOfTrngGeselWhoaaThatLosts3pOthalhappendAtl6ThoughStilTryint0oGetbene!"
# -----
# Write a short emotional tweet expressing anger: " So piss ed off I had to kick her out lmaoIll have sex no problem in our new location wumw."
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
#  WhatTheHeck!!?This guyisinlyForRamAndAlwaySpredBnSoIWassUnaHangandJustDepressedByNtwowavejmsimoneHoward#ImNoTimturbo!
# PROMPT:
# Write a short emotional tweet expressing anger: " Ready fognore these emails about jobstuff causeidonotWowire. HaveIthinksoilikemynewpastjobschoolprogramhappydayyooallandHit that nipple withabuttonassholestruckangrandmamatoattendfunkynomakegrampaThe"
# -----
# Write a short emotional tweet expressing anger: " WaitNThisUppityDawggie FOffYouShii yall tripping bout nthn uOwe mE..R weThdou no rathHer f0xNo #BlankSlide"
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
#  AngryBlack Lady Here my queen itsabout damTyme ppl gossip  oF dat sweet Afrikan Honey can not do mathemewhen did TrumpsName up? They want Ima take orders for all their trashNeeds in hand bag or plast
# PROMPT:
# Write a short emotional tweet expressing anger: " How could u lie like that? Imangr  this hurts My soul has been ripped in2. Not noooope naaaah!"
# -----
# Write a short emotional tweet expressing anger: " Thats the end result of months Of waiting my fiancs medical can get treatment thanks you now"
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
#  Can I say thankful... He said his best friend Will buy me stuff while he recover for surgery after it
# PROMPT:
# Write a short emotional tweet expressing anger: " Tears were cried in Apples#NewHampshire .Why could she simply walk on down but then yher boyfriodg came from NOWHERE.. just hugged her soo tightno word and them kept pushing all over HER TO G! teffF "
# -----
# Write a short emotional tweet expressing anger: " w0tf J3 s2ll KArEndl yElOs Gowld OylIlBl BrNts gEng Plss Do thx!"
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
#  Shes supposed to b married for life with that piece of junk.
# PROMPT:
# Write a short emotional tweet expressing anger: " OMG... My mind as blown and the shock gotten worst day Ever lest us piss off Tinky Witch now.. Hes baaaccdddaah whew heal me! Smd #CrownVampTayyy!"
# -----
# Write a short emotional tweet expressing anger: " They didnt let that !# doctors note hold them down he gone toooo. #teamNo"
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
#  Just seen his comment in comments to another vidoe so much love going towards my son from here keep spreadinfng smiles him truly needs it but whatever shits conselingd has stopped seeing nothing more
# EXAMPLE:
#  Like? If we would had some good for naught then you should be so grateful . We gave her ? 48 but no they really did get one million smd frglz Yoda?
# PROMPT:
# Write a short emotional tweet expressing anger: " What rong? says da fye mfer...but DERES ALKIN IN IT SO U KNO WHAT GOING ONZ YU NOT ROAN RIIT AND TEH ENTz."
# -----
# Write a short emotional tweet expressing anger: " Just wondering what was truly going on? Uh okay..still angry...#mixedemotion"
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
#  My feelings are like lukewarm and ready to SAAAAAAVE THE DAY! #justangerventilate
# PROMPT:
# Write a short emotional tweet expressing anger: " Happy that these creatures still want an make America gRain their little ways instead of taking cOloN as FINALa ILY SMe it up like #DArKSiDe."
# -----
# Write a short emotional tweet expressing anger: " New York city finally lifting indoor mask mandate...about time this joke of an epidemic ends soon and normalcy resumes bcause hiding under cars while having piss flavored mouth aint doing muchforus a"
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
# Soo happy the federal judge has allowed#YAllTerritoryZElP to stay shutdOWn THE CURRESe oF INComOrIng rulinG coUntrypoSoThs reCounTRys doUhNo mATterAgAIns ThEm iLlByIt until wE start worshippAncing AT
# PROMPT:
# Write a short emotional tweet expressing anger: " Fine Natasharogers is using your son like u was saying before all eyes closed from one state far way now every where with new recruits we gon hold his breath I cannot brew."
# -----
# Write a short emotional tweet expressing anger: " Did I ever tell you abouthttpsy dLosti! F#K THIS DAY Man!! MOnStayB4Illmwake urantPandAsChicken and his cocks for real he wants us to fight (stroppycat8296). This might seem weird but plz keep using "
# -----
# Write a short emotional tweet expressing anger:
# EXAMPLE:
#  Absolutely Kierraaa this pissinme off why are people always lyunatic AS L long as tho fkn parrens on me iamkngill just shut my crap in chancled. Now do these tiny ynd riddl PTbhW0HtE #iMea.
# EXAMPLE:
#  YoullNeverIce okayAaronPaul lets Get It RightTheCockBroSos...TheyToldUwe on fire smh theGameNotMeRagingbabyyoussay yasusaysome1MydadsSpurthePlat MyWineWhenICouldHaveDpinedGivesMoThoNeitherArEntShifti

# %%
#Remose seeded entries from dataset: run only once
curr_df = pd.read_csv(datapath + filename)
curr_df = curr_df.drop([i for i in range(1,len(label_to_label_name)*2)])
curr_df.to_csv(datapath + filename, index=False)
